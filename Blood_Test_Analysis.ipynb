# %%
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
load_dotenv()
llm=ChatGoogleGenerativeAI(model="gemma-4-31b-it")

# %%
with open("Blood_Test_Report.txt","r") as f:
    blood_test=f.read()
print(blood_test[:200])
# Out:
# Patient: Rajesh Sharma, Age 48, Male
# Date: May 7, 2026
#
# COMPLETE BLOOD COUNT (CBC)
# --------------------------
# Hemoglobin:        15.1 g/dL        (Normal: 13.5â€“17.5)
# Hematocrit:        44%

# %%
extraction_prompt=f"""
You are a model data extraction assistant.

From the Blood report below, extract all test values and classify each one as HIGH, LOW, or NORMAL
based on the referance ranges provided in the report.

Format your Response as:
- Test Name: value | Status: HIGH/LOW/NORMAL | Reference: Range

Blood Report:
{blood_test}
"""

extraction_response=llm.invoke(extraction_prompt)

print("== STAGE 1: Extraction Values ==")
print(extraction_response.text)
# Out:
# == STAGE 1: Extraction Values ==
# - Hemoglobin: 15.1 g/dL | Status: NORMAL | Reference: 13.5–17.5
# - Hematocrit: 44% | Status: NORMAL | Reference: 41–53%
# - WBC: 6.8 x10^3/uL | Status: NORMAL | Reference: 4.5–11.0
# - Platelets: 220 x10^3/uL | Status: NORMAL | Reference: 150–400
# - Total Cholesterol: 238 mg/dL | Status: HIGH | Reference: <200
# - LDL Cholesterol: 162 mg/dL | Status: HIGH | Reference: <100
# - HDL Cholesterol: 36 mg/dL | Status: LOW | Reference: >40
# - Triglycerides: 188 mg/dL | Status: HIGH | Reference: <150
# - Glucose (Fasting): 92 mg/dL | Status: NORMAL | Reference: 70–99
# - HbA1c: 5.3% | Status: NORMAL | Reference: <5.7%
# - Creatinine: 1.0 mg/dL | Status: NORMAL | Reference: 0.7–1.3
# - eGFR: 82 mL/min | Status: NORMAL | Reference: >60
# - ALT: 28 U/L | Status: NORMAL | Reference: 7–40
# - AST: 25 U/L | Status: NORMAL | Reference: 10–40
# - Bilirubin Total: 0.8 mg/dL | Status: NORMAL | Reference: 0.2–1.2

# %% [markdown]
# **Suggesting the Diet plan acc. to the Test Report**

# %%
diet_prompt=f"""
You are a Clinical Nutritionist specializing in Indian Ovo-lecto-Vegetarian Dietry habits.

Based on the blood work analysis below, write:
1. A short health summary in 4-5 lines explaining the Patient's Condition in simple language
2. A short practical Indian Vegetarian diet plan having only two section (1) Foods to avoid (2) Foods to eat more of.

Blood Work Analysis:
{extraction_response}
"""

diet_response=llm.invoke(diet_prompt)

print("== Stage 2: health Summary & Diet Plan ==")
print(diet_response.text)
# Out:
# == Stage 2: health Summary & Diet Plan ==
# **Health Summary**
# Your blood reports indicate that your blood sugar, kidney, and liver functions are all within the healthy range. However, you have an imbalance in your lipid profile (cholesterol). Specifically, your "bad" cholesterol (LDL) and triglycerides are too high, while your "good" cholesterol (HDL) is too low. Improving this balance through diet and activity is essential to maintain long-term heart health.
#
# **Indian Vegetarian Diet Plan**
#
# **1. Foods to Avoid**
# *   **Deep-Fried Foods:** Samosas, pakoras, puris, and namkeens.
# *   **Refined Carbohydrates:** Maida-based products (white bread, naan, biscuits) and sugary sweets/mithai.
# *   **Saturated & Trans Fats:** Excessive ghee, butter, palm oil, and vanaspati.
# *   **Full-Fat Dairy:** Full-cream milk, heavy cream, and high-fat paneer.
# *   **Processed Snacks:** Packaged chips and sugary carbonated drinks.
#
# **2. Foods to Eat More Of**
# *   **Whole Grains:** Oats, daliya (broken wheat), brown rice, and millets (jowar, bajra, ragi).
# *   **Legumes & Pulses:** Moong dal, chickpeas (chole), kidney beans (rajma), and sprouts.
# *   **Omega-3 Rich Seeds & Nuts:** Walnuts, almonds, flaxseeds, and chia seeds (to help increase HDL).
# *   **Fiber-Rich Vegetables:** Leafy greens (spinach, methi), okra, broccoli, garlic, and bottle gourd.
# *   **Fresh Fruits:** Apples, papaya, guava, and citrus fruits (citrus helps lower LDL).
# *   **Healthy Cooking Oils:** Use mustard oil, olive oil, or rice bran oil in limited quantities.
